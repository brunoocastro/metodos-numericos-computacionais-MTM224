# %%
import numpy as np
from lib.ajuste_curvas.minimos_quadrados import MetodoMinimosQuadrados

# %%
X = [1, 2, 3, 4]
Y = [2, 3, 5, 4]
degree = 3  # Grau do polinômio

# %%
minimos_quadrados = MetodoMinimosQuadrados(X, Y, degree)
# Out:
# Matriz A:
# [[ 1.  1.  1.  1.]
#  [ 1.  2.  4.  8.]
#  [ 1.  3.  9. 27.]
#  [ 1.  4. 16. 64.]]

# %%
minimos_quadrados.findCoefficients()
# Out:
# Solution Matrix:
# [[ 1.00000000e+02  3.54000000e+02  1.30000000e+03  4.89000000e+03
#    4.17000000e+02]
#  [ 0.00000000e+00 -6.20000000e+00 -3.60000000e+01 -1.67000000e+02
#   -2.10000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  2.15483871e+00  1.64516129e+01
#   -1.27096774e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.07784431e-01
#   -7.18562874e-02]]
# AUpper:
# [[ 1.00000000e+02  3.54000000e+02  1.30000000e+03  4.89000000e+03]
#  [ 0.00000000e+00 -6.20000000e+00 -3.60000000e+01 -1.67000000e+02]
#  [ 0.00000000e+00  0.00000000e+00  2.15483871e+00  1.64516129e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.07784431e-01]]
# BUpper:
# [[ 4.17000000e+02]
#  [-2.10000000e+00]
#  [-1.27096774e+00]
#  [-7.18562874e-02]]
# (4, 1) (4, 4)
# Matriz é triangular superior
# Received Matrix A:
# [[ 1.00000000e+02  3.54000000e+02  1.30000000e+03  4.89000000e+03]
#  [ 0.00000000e+00 -6.20000000e+00 -3.60000000e+01 -1.67000000e+02]
#  [ 0.00000000e+00  0.00000000e+00  2.15483871e+00  1.64516129e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.07784431e-01]]
# Received Vector B:
# [[ 4.17000000e+02]
#  [-2.10000000e+00]
#  [-1.27096774e+00]
#  [-7.18562874e-02]]
# Variation interval for I: range(2, -1, -1)                  with shape (0,3)
# Variation Interval for J: range(1, 4)
# Initial Solution: [ 0.          0.          0.         -0.66666667]
# i: 2
# i: 2, j: 3, sum: -10.96774193547941
# Solution:
# [ 0.          0.          4.5        -0.66666667]
#
# i: 1
# i: 1, j: 2, sum: -161.9999999999261
# i: 1, j: 3, sum: -50.66666666663778
# Solution:
# [ 0.         -7.83333333  4.5        -0.66666667]
#
# i: 0
# i: 0, j: 1, sum: -2772.9999999983497
# i: 0, j: 2, sum: 3076.999999998982
# i: 0, j: 3, sum: -182.99999999970032
# Solution:
# [ 6.         -7.83333333  4.5        -0.66666667]
#
# Solution: [ 6.     -7.8333  4.5    -0.6667]

# %%
print("Coefficients of the polynomial:\n", minimos_quadrados.coefficients)
# Out:
# Coefficients of the polynomial:
#  [ 6.     -7.8333  4.5    -0.6667]

# %%
minimos_quadrados.plotDataAndFit()

# %% [markdown]
# # Exemplo da aula de apresentação

# %%
A = [1, 2, 3, 4]
b = [2, 3, 5, 4]

degree = 3

# %%
# Exercício da aula
minimos_quadrados = MetodoMinimosQuadrados(A, b, degree)
# Out:
# Matriz A:
# [[ 1.  1.  1.  1.]
#  [ 1.  2.  4.  8.]
#  [ 1.  3.  9. 27.]
#  [ 1.  4. 16. 64.]]

# %%
minimos_quadrados.findCoefficients()
# Out:
# Solution Matrix:
# [[ 1.00000000e+02  3.54000000e+02  1.30000000e+03  4.89000000e+03
#    4.17000000e+02]
#  [ 0.00000000e+00 -6.20000000e+00 -3.60000000e+01 -1.67000000e+02
#   -2.10000000e+00]
#  [ 0.00000000e+00  0.00000000e+00  2.15483871e+00  1.64516129e+01
#   -1.27096774e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.07784431e-01
#   -7.18562874e-02]]
# AUpper:
# [[ 1.00000000e+02  3.54000000e+02  1.30000000e+03  4.89000000e+03]
#  [ 0.00000000e+00 -6.20000000e+00 -3.60000000e+01 -1.67000000e+02]
#  [ 0.00000000e+00  0.00000000e+00  2.15483871e+00  1.64516129e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.07784431e-01]]
# BUpper:
# [[ 4.17000000e+02]
#  [-2.10000000e+00]
#  [-1.27096774e+00]
#  [-7.18562874e-02]]
# (4, 1) (4, 4)
# Matriz é triangular superior
# Received Matrix A:
# [[ 1.00000000e+02  3.54000000e+02  1.30000000e+03  4.89000000e+03]
#  [ 0.00000000e+00 -6.20000000e+00 -3.60000000e+01 -1.67000000e+02]
#  [ 0.00000000e+00  0.00000000e+00  2.15483871e+00  1.64516129e+01]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  1.07784431e-01]]
# Received Vector B:
# [[ 4.17000000e+02]
#  [-2.10000000e+00]
#  [-1.27096774e+00]
#  [-7.18562874e-02]]
# Variation interval for I: range(2, -1, -1)                  with shape (0,3)
# Variation Interval for J: range(1, 4)
# Initial Solution: [ 0.          0.          0.         -0.66666667]
# i: 2
# i: 2, j: 3, sum: -10.96774193547941
# Solution:
# [ 0.          0.          4.5        -0.66666667]
#
# i: 1
# i: 1, j: 2, sum: -161.9999999999261
# i: 1, j: 3, sum: -50.66666666663778
# Solution:
# [ 0.         -7.83333333  4.5        -0.66666667]
#
# i: 0
# i: 0, j: 1, sum: -2772.9999999983497
# i: 0, j: 2, sum: 3076.999999998982
# i: 0, j: 3, sum: -182.99999999970032
# Solution:
# [ 6.         -7.83333333  4.5        -0.66666667]
#
# Solution: [ 6.     -7.8333  4.5    -0.6667]

# %%
print("Coeficientes do polinômio:\n", minimos_quadrados.coefficients)
# Out:
# Coeficientes do polinômio:
#  [ 6.     -7.8333  4.5    -0.6667]

# %%
minimos_quadrados.plotDataAndFit()

# %%
vetorX = [ -3, -1,  1,  2,  3]
vetorY = [ -1,  0,  1,  1, -1]

degree = 3

# %%
minimos_quadrados = MetodoMinimosQuadrados(vetorX, vetorY, degree)
# Out:
# Matriz A:
# [[  1.  -3.   9. -27.]
#  [  1.  -1.   1.  -1.]
#  [  1.   1.   1.   1.]
#  [  1.   2.   4.   8.]
#  [  1.   3.   9.  27.]]

# %%
minimos_quadrados.findCoefficients()
# Out:
# Solution Matrix:
# [[ 2.40000000e+01  8.00000000e+00  1.80000000e+02  3.20000000e+01
#   -1.30000000e+01]
#  [ 0.00000000e+00  1.77333333e+02 -2.80000000e+01  1.51333333e+03
#    1.33333333e+01]
#  [ 0.00000000e+00  0.00000000e+00 -1.34473684e+01 -1.51127820e+00
#    2.68327068e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -2.14168297e+01
#    1.66731898e+00]]
# AUpper:
# [[ 2.40000000e+01  8.00000000e+00  1.80000000e+02  3.20000000e+01]
#  [ 0.00000000e+00  1.77333333e+02 -2.80000000e+01  1.51333333e+03]
#  [ 0.00000000e+00  0.00000000e+00 -1.34473684e+01 -1.51127820e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -2.14168297e+01]]
# BUpper:
# [[-13.        ]
#  [ 13.33333333]
#  [  2.68327068]
#  [  1.66731898]]
# (4, 1) (4, 4)
# Matriz é triangular superior
# Received Matrix A:
# [[ 2.40000000e+01  8.00000000e+00  1.80000000e+02  3.20000000e+01]
#  [ 0.00000000e+00  1.77333333e+02 -2.80000000e+01  1.51333333e+03]
#  [ 0.00000000e+00  0.00000000e+00 -1.34473684e+01 -1.51127820e+00]
#  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00 -2.14168297e+01]]
# Received Vector B:
# [[-13.        ]
#  [ 13.33333333]
#  [  2.68327068]
#  [  1.66731898]]
# Variation interval for I: range(2, -1, -1)                  with shape (0,3)
# Variation Interval for J: range(1, 4)
# Initial Solution: [ 0.          0.          0.         -0.07785088]
# i: 2
# i: 2, j: 3, sum: 0.11765433320142474
# Solution:
# [ 0.          0.         -0.19078947 -0.07785088]
#
# i: 1
# i: 1, j: 2, sum: 5.342105263157895
# i: 1, j: 3, sum: -112.4722222222224
# Solution:
# [ 0.          0.70942982 -0.19078947 -0.07785088]
#
# i: 0
# i: 0, j: 1, sum: 5.675438596491236
# i: 0, j: 2, sum: -28.66666666666666
# i: 0, j: 3, sum: -31.157894736842103
# Solution:
# [ 0.75657895  0.70942982 -0.19078947 -0.07785088]
#
# Solution: [ 0.7566  0.7094 -0.1908 -0.0779]

# %%
minimos_quadrados.plotDataAndFit()

# %%
minimos_quadrados.coefficients
# Out:
# array([ 0.7566,  0.7094, -0.1908, -0.0779])
