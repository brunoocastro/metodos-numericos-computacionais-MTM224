# %%
import numpy as np
from lib.ajuste_curvas.minimos_quadrados import MetodoMinimosQuadrados

# %%
X = [1, 2, 3, 4]
Y = [2, 3, 5, 4]
degree = 3  # Grau do polinômio

# %%
minimos_quadrados = MetodoMinimosQuadrados(X, Y, degree)
# Out:
# A

# %%
minimos_quadrados.fit()
# Out:
# Solution matrix POS PIVOT CHANGES:
# [[1.00e+02 3.54e+02 1.30e+03 4.89e+03 4.17e+02]
#  [1.00e+01 3.00e+01 1.00e+02 3.54e+02 3.90e+01]
#  [3.00e+01 1.00e+02 3.54e+02 1.30e+03 1.23e+02]
#  [4.00e+00 1.00e+01 3.00e+01 1.00e+02 1.40e+01]]
#
# Factor in [1,0]: 0.1
# Linha i: [ 10.  30. 100. 354.  39.]
# Linha j: [ 100.  354. 1300. 4890.  417.]
# Final: [   0.    -5.4  -30.  -135.    -2.7]
# Solution matrix on [1,0]:
#  [[ 1.00e+02  3.54e+02  1.30e+03  4.89e+03  4.17e+02]
#  [ 0.00e+00 -5.40e+00 -3.00e+01 -1.35e+02 -2.70e+00]
#  [ 3.00e+01  1.00e+02  3.54e+02  1.30e+03  1.23e+02]
#  [ 4.00e+00  1.00e+01  3.00e+01  1.00e+02  1.40e+01]]
#
#
# Solution matrix POS PIVOT CHANGES:
# [[ 1.00e+02  3.54e+02  1.30e+03  4.89e+03  4.17e+02]
#  [ 0.00e+00 -5.40e+00 -3.00e+01 -1.35e+02 -2.70e+00]
#  [ 3.00e+01  1.00e+02  3.54e+02  1.30e+03  1.23e+02]
#  [ 4.00e+00  1.00e+01  3.00e+01  1.00e+02  1.40e+01]]
#
# Factor in [2,0]: 0.3
# Linha i: [  30.  100.  354. 1300.  123.]
# ...

# %%
print("Coefficients of the polynomial:\n", minimos_quadrados.coefficients)
# Out:
# Coefficients of the polynomial:
#  [ 6.     -7.8333  4.5    -0.6667]

# %%
minimos_quadrados.plotDataAndFit()
# Out:
# A

# %% [markdown]
# # Exemplo da aula de apresentação

# %%
A = [1, 2, 3, 4]
b = [2, 3, 5, 4]

degree = 4

# %%
# Exercício da aula
minimos_quadrados = MetodoMinimosQuadrados(A, b, degree)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Exercício da aula
# ----> 2 minimos_quadrados = MetodoMinimosQuadrados(A, b, degree)
#
# File ~/www/study/metodos-numericos-computacionais-MTM224/lib/ajuste_curvas/minimos_quadrados.py:15, in MetodoMinimosQuadrados.__init__(self, X, Y, degree)
#      12 self.degree = degree
#      14 if self.degree >= len(self.X):
# ---> 15     raise ValueError(
#      16         f"O grau do polinômio deve ser no máximo igual (N - 1) para\
#      17          X com tamanho N.\nNeste caso o grau máximo é {len(self.X) - 1}"
#      18     )
#      20 self.designMatrix = self.createDesignMatrix(self.X, self.degree)
#      21 self.coefficients = None
#
# ValueError: O grau do polinômio deve ser no máximo igual (N - 1) para                 X com tamanho N.
# Neste caso o grau máximo é 3

# %%
minimos_quadrados.fit()
# Out:
# Solution matrix POS PIVOT CHANGES:
# [[3.5400e+02 1.3000e+03 4.8900e+03 1.8700e+04 7.2354e+04 1.4790e+03]
#  [1.0000e+01 3.0000e+01 1.0000e+02 3.5400e+02 1.3000e+03 3.9000e+01]
#  [3.0000e+01 1.0000e+02 3.5400e+02 1.3000e+03 4.8900e+03 1.2300e+02]
#  [1.0000e+02 3.5400e+02 1.3000e+03 4.8900e+03 1.8700e+04 4.1700e+02]
#  [4.0000e+00 1.0000e+01 3.0000e+01 1.0000e+02 3.5400e+02 1.4000e+01]]
#
# Factor in [1,0]: 0.02824858757062147
# Linha i: [  10.   30.  100.  354. 1300.   39.]
# Linha j: [  354.  1300.  4890. 18700. 72354.  1479.]
# Final: [   0.           -6.72316384  -38.13559322 -174.24858757 -743.89830508
#    -2.77966102]
# Solution matrix on [1,0]:
#  [[ 3.54000000e+02  1.30000000e+03  4.89000000e+03  1.87000000e+04
#    7.23540000e+04  1.47900000e+03]
#  [ 0.00000000e+00 -6.72316384e+00 -3.81355932e+01 -1.74248588e+02
#   -7.43898305e+02 -2.77966102e+00]
#  [ 3.00000000e+01  1.00000000e+02  3.54000000e+02  1.30000000e+03
#    4.89000000e+03  1.23000000e+02]
# ...

# %%
print("Coeficientes do polinômio:\n", minimos_quadrados.coefficients)
# Out:
# Coeficientes do polinômio:
#  [nan nan nan nan nan]

# %%
minimos_quadrados.plotDataAndFit()
# Out:
# A
