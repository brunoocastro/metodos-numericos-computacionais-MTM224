# %%
import numpy as np
from lib.integracao_numerica.integracao_numerica import IntegracaoNumerica

# %%
def func(x):
    return np.sin(x)

a = 0
b = 3.1415
n = 50

# %%
integracao = IntegracaoNumerica(a,b,n, func)

# %%
integracao.trapezoidal_rule()
# Out:
# Área aproximada sob a curva de 0 a 3.1415 com 50 trapézios: 1.99934201760051
# np.float64(1.99934201760051)

# %%
integracao.plot()

# %%
def func2(x):
    return np.sqrt(x)

a2 = 1
b2 = 2
n2 = 50

# %%
integracao2 = IntegracaoNumerica(a2,b2,n2, func2)

# %%
integracao2.trapezoidal_rule()
# Out:
# Área aproximada sob a curva de 1 a 2 com 50 trapézios: 1.2189465350124082
# np.float64(1.2189465350124082)

# %%
integracao2.plot()
