# %%
from lib.zeros_funcoes.secantes import Secantes
import numpy as np

# %%
f = lambda x: 2*x * np.cos(2*x) - (x+1)**2
max_iterations = 1000
epsilon = 1e-4
x0 = 0.30
x1 = 0.35

# %%
alg = Secantes(f,x0, x1, epsilon, max_iterations)

# %%
alg.calculate_root()
# Out:
# Iteração 1: -0.3471535281524869
# Erro pela imagem: 2.2714959137667226
# Erro pelo domínio: 2.0081994610933718
#
# Iteração 2: -2.391321245610852
# Erro pela imagem: 6.141925642825735
# Erro pelo domínio: 0.8548277322464854
#
# Iteração 3: 1.148564337898268
# Erro pela imagem: 4.13471375639489
# Erro pelo domínio: 3.082008962586003
#
# Iteração 4: -4.468825864225282
# Erro pela imagem: 251.46224333548358
# Erro pelo domínio: 1.2570170270211196
#
# Iteração 5: -16.040250236894938
# Erro pela imagem: 5.240662554998696
# Erro pelo domínio: 0.7213992426410951
#
# Iteração 6: -4.275379838964026
# Erro pela imagem: 7.583042359463228
# Erro pelo domínio: 2.751771969056596
#
# Iteração 7: -4.024972398789977
# Erro pela imagem: 5.333014826123129
# Erro pelo domínio: 0.06221345523992387
#
# Iteração 8: -4.835622414788833
# Erro pela imagem: 41.02972013810516
# Erro pelo domínio: 0.1676412975338267
#
# Iteração 9: -6.75702492656218
# Erro pela imagem: 3.9791312202256552
# ...

# %%
alg.show_final_table()
