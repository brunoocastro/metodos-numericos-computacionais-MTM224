# %%
import numpy as np
from lib.zeros_funcoes.falsa_posicao import FalsaPosicao

# %%
f_bernardo = lambda x: x * np.cos(x) - 2 * x**2 + 3*x - 1

a = 0
b = np.pi / 4
epsilon = 0.001
res = FalsaPosicao(f_bernardo, a, b, epsilon)

res.calculate_root()
res.show_final_table()
# Out:
# Método finalizado pela imagem.
# Raiz (pm): 0.2976026998843263 e F(pm): 0.00019410380160134189

# %%
faula = lambda x: 4*np.cos(x) - np.exp(2*x)
epsilon = 0.001
a = 0.5
b = 0.6

falsapos = FalsaPosicao(faula, a, b, epsilon)
falsapos.calculate_root()
falsapos.show_final_table()
# Out:
# Método finalizado pela imagem.
# Raiz (pm): 0.5978860662559997 e F(pm): 6.929180340620178e-09

# %%
farthur = lambda x: x * np.cos(x) - 2* x**2 + 3*x - 1
epsilon = 0.001

a = 1
b = 1.3

fp = FalsaPosicao(farthur, a, b, epsilon)
fp.calculate_root()
fp.show_final_table()
# Out:
# Método finalizado pela imagem.
# Raiz (pm): 1.2566219021378477 e F(pm): 4.136924995457036e-06
